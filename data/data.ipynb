# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("sample_data.csv")

# %%
df.head(100)
# Out:
#    PROJECT_ID   PM   TASK_ID                START                  END  \
# 0      213494  KMT  10048285  2014/11/26 10:36:00  2014/11/26 15:30:00
# 1      214198  KMT  10048285  2015/09/09 17:29:00  2015/09/10 11:00:00
# 2      213094  PMT  10048285  2014/05/01 19:27:00  2014/05/02 19:00:00
# 3      211967  KMT  10048285  2013/07/17 17:40:00  2013/08/31 18:00:00
# 4      212331  PMT  10048285  2013/11/01 13:13:00  2013/10/31 19:00:00
# ..        ...  ...       ...                  ...                  ...
# 95     207290  BMT  10112709  2010/01/05 17:20:00  2010/01/08 12:00:00
# 96     207317  PMT  10112710  2010/01/07 09:34:00  2010/01/07 13:00:00
# 97     207317  PMT  10112712  2010/01/07 09:38:00  2010/01/07 12:30:00
# 98     207317  PMT  10112713  2010/01/07 12:30:00  2010/01/07 14:00:00
# 99     207331  BMT  10112714  2010/01/07 09:43:00  2010/01/11 09:00:00
#
#         TASK_TYPE SOURCE_LANG          TARGET_LANG       TRANSLATOR  \
# 0     Engineering     English  Portuguese (Brazil)           Estela
# 1     Engineering     English    Spanish (Iberian)         Jeronimo
# 2     Engineering     Catalan              Catalan           Octavi
# 3      Management     English    Spanish (Iberian)   Ramiro Josafat
# 4   Miscellaneous     Catalan              Catalan           Victor
# ..            ...         ...                  ...              ...
# 95    Translation     English    Spanish (Iberian)  Salma Benedicto
# 96   ProofReading     English    Spanish (Iberian)  Almudena Fiamma
# 97    Translation     English    Spanish (Iberian)  Almudena Fiamma
# 98   ProofReading     English    Spanish (Iberian)      Luis Felipe
# 99    Translation     English    Spanish (Iberian)          Basileo
#
#                ASSIGNED  ...                CLOSE FORECAST HOURLY_RATE  \
# 0   2014/11/26 16:34:23  ...  2014/11/26 17:51:48     0,25          24
# 1   2015/09/09 17:31:52  ...  2015/09/10 17:33:07      1,5          20
# 2   2014/05/02 13:29:33  ...  2014/05/02 13:29:44     0,33          15
# 3   2013/07/22 15:35:11  ...  2013/08/31 16:28:18      0,5          20
# 4   2013/10/31 13:14:35  ...  2013/10/31 13:18:34        0          11
# ..                  ...  ...                  ...      ...         ...
# 95  2010/01/05 17:21:29  ...  2010/01/08 10:08:53     1,06          20
# 96  2010/01/07 09:34:34  ...  2010/01/07 12:53:18      0,6          21
# 97  2010/01/07 09:39:08  ...  2010/01/07 11:54:23      0,4          21
# 98  2010/01/07 09:39:08  ...  2010/01/07 11:54:22     0,12          19
# 99  2010/01/07 09:44:04  ...  2010/01/08 09:22:20      9,6          22
#
#                   COST QUALITY_EVALUATION              MANUFACTURER  \
# 0                    6                  7           Coastal Cottage
# 1                   30                  7               HealthyLife
# 2                 4,95                  6               AeroSysTech
# 3                   10                  6                   MetaPro
# 4                    0                  8                   SunTech
# ..                 ...                ...                       ...
# 95  21,200000000000003                  6              DesarrolloYa
# 96                12,6                  5  Global Trading Solutions
# 97                 8,4                  8  Global Trading Solutions
# 98                2,28                  7  Global Trading Solutions
# 99               211,2                  8                 Flux Fuel
#
#        MANUFACTURER_SECTOR      MANUFACTURER_INDUSTRY_GROUP  \
# 0   Consumer Discretionary                Consumer Services
# 1              Health Care            Health Care Providers
# 2   Information Technology              Software & Services
# 3              Industrials             Electrical Equipment
# 4   Information Technology  Technology Hardware & Equipment
# ..                     ...                              ...
# 95  Information Technology  Technology Hardware & Equipment
# 96             Industrials                    Capital Goods
# 97             Industrials                    Capital Goods
# 98             Industrials                    Capital Goods
# 99  Information Technology              Software & Services
#
#                          MANUFACTURER_INDUSTRY  \
# 0                Hotels, Restaurants & Leisure
# 1                       Health Care Facilities
# 2                         Application Software
# 3            Electrical Components & Equipment
# 4   Technology Hardware, Storage & Peripherals
# ..                                         ...
# 95  Technology Hardware, Storage & Peripherals
# 96            Trading Companies & Distributors
# 97            Trading Companies & Distributors
# 98            Trading Companies & Distributors
# 99                        Application Software
#
#                       MANUFACTURER_SUBINDUSTRY
# 0               Hotels, Resorts & Cruise Lines
# 1                    Long-Term Care Facilities
# 2                             Systems Software
# 3            Electrical Components & Equipment
# 4   Technology Hardware, Storage & Peripherals
# ..                                         ...
# 95  Technology Hardware, Storage & Peripherals
# 96            Trading Companies & Distributors
# 97            Trading Companies & Distributors
# 98            Trading Companies & Distributors
# 99                        Application Software
#
# [100 rows x 24 columns]

# %%
df.describe()
# Out:
#             TASK_ID   HOURLY_RATE  QUALITY_EVALUATION
# count  3.101700e+04  31017.000000        31017.000000
# mean   1.012960e+07     19.036851            6.984041
# std    9.893531e+03      3.513363            1.419142
# min    1.004828e+07     10.000000            0.000000
# 25%    1.012117e+07     17.000000            6.000000
# 50%    1.012970e+07     19.000000            7.000000
# 75%    1.013807e+07     21.000000            8.000000
# max    1.014648e+07     51.000000           10.000000

# %%
fig, ax = plt.subplots()
df['TASK_TYPE'].value_counts().plot(ax=ax, kind='bar')
# Out:
# <Axes: xlabel='TASK_TYPE'>

# %%
df['TARGET_LANG'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='TARGET_LANG'>

# %%
df['SOURCE_LANG'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='SOURCE_LANG'>
