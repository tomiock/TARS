# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../data/data_enhanced.csv", decimal=".")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df = pd.read_csv("../data/data_enhanced.csv", decimal=".")
#
# File /nix/store/zjha45qfiag69rr822dc29qf8fnhp8wm-python3.12-pandas-2.2.3/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File /nix/store/zjha45qfiag69rr822dc29qf8fnhp8wm-python3.12-pandas-2.2.3/lib/python3.12/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File /nix/store/zjha45qfiag69rr822dc29qf8fnhp8wm-python3.12-pandas-2.2.3/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File /nix/store/zjha45qfiag69rr822dc29qf8fnhp8wm-python3.12-pandas-2.2.3/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File /nix/store/zjha45qfiag69rr822dc29qf8fnhp8wm-python3.12-pandas-2.2.3/lib/python3.12/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/data_enhanced.csv'

# %%
df.head(100)
# Out:
#     Unnamed: 0 PROJECT_ID   PM   TASK_ID                START  \
# 0            0     213494  KMT  10048285  26/11/2014 10:36:00
# 1            1     214198  KMT  10048285  09/09/2015 17:29:00
# 2            2     213094  PMT  10048285  01/05/2014 19:27:00
# 3            3     211967  KMT  10048285  17/07/2013 17:40:00
# 4            4     212331  PMT  10048285  01/11/2013 13:13:00
# ..         ...        ...  ...       ...                  ...
# 95          95     207290  BMT  10112709  05/01/2010 17:20:00
# 96          96     207317  PMT  10112710  07/01/2010 09:34:00
# 97          97     207317  PMT  10112712  07/01/2010 09:38:00
# 98          98     207317  PMT  10112713  07/01/2010 12:30:00
# 99          99     207331  BMT  10112714  07/01/2010 09:43:00
#
#                     END      TASK_TYPE SOURCE_LANG          TARGET_LANG  \
# 0   26/11/2014 15:30:00    Engineering     English  Portuguese (Brazil)
# 1   10/09/2015 11:00:00    Engineering     English    Spanish (Iberian)
# 2   02/05/2014 19:00:00    Engineering     Catalan              Catalan
# 3   31/08/2013 18:00:00     Management     English    Spanish (Iberian)
# 4   31/10/2013 19:00:00  Miscellaneous     Catalan              Catalan
# ..                  ...            ...         ...                  ...
# 95  08/01/2010 12:00:00    Translation     English    Spanish (Iberian)
# 96  07/01/2010 13:00:00   ProofReading     English    Spanish (Iberian)
# 97  07/01/2010 12:30:00    Translation     English    Spanish (Iberian)
# 98  07/01/2010 14:00:00   ProofReading     English    Spanish (Iberian)
# 99  11/01/2010 09:00:00    Translation     English    Spanish (Iberian)
#
#          TRANSLATOR  ... QUALITY_EVALUATION              MANUFACTURER  \
# 0            Estela  ...                  7           Coastal Cottage
# 1          Jeronimo  ...                  7               HealthyLife
# 2            Octavi  ...                  6               AeroSysTech
# 3    Ramiro Josafat  ...                  6                   MetaPro
# 4            Victor  ...                  8                   SunTech
# ..              ...  ...                ...                       ...
# 95  Salma Benedicto  ...                  6              DesarrolloYa
# 96  Almudena Fiamma  ...                  5  Global Trading Solutions
# 97  Almudena Fiamma  ...                  8  Global Trading Solutions
# 98      Luis Felipe  ...                  7  Global Trading Solutions
# 99          Basileo  ...                  8                 Flux Fuel
#
#        MANUFACTURER_SECTOR      MANUFACTURER_INDUSTRY_GROUP  \
# 0   Consumer Discretionary                Consumer Services
# 1              Health Care            Health Care Providers
# 2   Information Technology              Software & Services
# 3              Industrials             Electrical Equipment
# 4   Information Technology  Technology Hardware & Equipment
# ..                     ...                              ...
# 95  Information Technology  Technology Hardware & Equipment
# 96             Industrials                    Capital Goods
# 97             Industrials                    Capital Goods
# 98             Industrials                    Capital Goods
# 99  Information Technology              Software & Services
#
#                          MANUFACTURER_INDUSTRY  \
# 0                Hotels, Restaurants & Leisure
# 1                       Health Care Facilities
# 2                         Application Software
# 3            Electrical Components & Equipment
# 4   Technology Hardware, Storage & Peripherals
# ..                                         ...
# 95  Technology Hardware, Storage & Peripherals
# 96            Trading Companies & Distributors
# 97            Trading Companies & Distributors
# 98            Trading Companies & Distributors
# 99                        Application Software
#
#                       MANUFACTURER_SUBINDUSTRY  _work_ready  _time_taken  \
# 0               Hotels, Resorts & Cruise Lines     0.000556     1.261111
# 1                    Long-Term Care Facilities     0.014444    23.109167
# 2                             Systems Software     0.000556     0.000556
# 3            Electrical Components & Equipment   936.324444     0.000833
# 4   Technology Hardware, Storage & Peripherals     0.000556     0.000556
# ..                                         ...          ...          ...
# 95  Technology Hardware, Storage & Peripherals    46.308056    16.080556
# 96            Trading Companies & Distributors     2.034722     0.584444
# 97            Trading Companies & Distributors     0.431667     0.233333
# 98            Trading Companies & Distributors     0.651667     0.225000
# 99                        Application Software     0.026389    22.855278
#
#     _time_reception  _time_to_close
# 0          0.027500        0.000556
# 1          0.845556        0.000556
# 2          0.000833        0.000556
# 3         24.552778        0.001111
# 4          0.000556        0.000833
# ..              ...             ...
# 95         2.383611        0.001111
# 96         0.685278        0.000000
# 97         1.566944        0.000000
# 98         0.624444        0.065556
# 99         0.676667        0.008056
#
# [100 rows x 29 columns]

# %%
df.describe()
# Out:
#          Unnamed: 0       TASK_ID      FORECAST   HOURLY_RATE          COST  \
# count  31017.000000  3.101700e+04  31017.000000  31017.000000  31017.000000
# mean   15508.000000  1.012960e+07      3.210721     19.036851     60.868110
# std     8953.980986  9.893531e+03      8.645564      3.513363    175.631388
# min        0.000000  1.004828e+07      0.000000     10.000000      0.000000
# 25%     7754.000000  1.012117e+07      0.170000     17.000000      3.200000
# 50%    15508.000000  1.012970e+07      0.710000     19.000000     13.260000
# 75%    23262.000000  1.013807e+07      2.490000     21.000000     46.000000
# max    31016.000000  1.014648e+07    324.830000     51.000000   7146.260000
#
#        QUALITY_EVALUATION   _work_ready   _time_taken  _time_reception  \
# count        31017.000000  31016.000000  31015.000000     31016.000000
# mean             6.984041     13.612837     19.853383         6.607568
# std              1.419142     52.121905     80.207250        56.520275
# min              0.000000      0.000000      0.000000         0.000000
# 25%              6.000000      0.083056      0.001667         0.018611
# 50%              7.000000      1.163472      0.658611         0.236667
# 75%              8.000000      9.321042      6.170833         1.693819
# max             10.000000   4370.539444   6668.523611      4371.611667
#
#        _time_to_close
# count    31017.000000
# mean         4.858361
# std         47.786571
# min          0.000000
# 25%          0.000278
# 50%          0.000556
# 75%          0.000833
# max       4176.480833

# %%
fig, ax = plt.subplots()
df['TASK_TYPE'].value_counts().plot(ax=ax, kind='bar')
# Out:
# <Axes: xlabel='TASK_TYPE'>

# %%
df['TARGET_LANG'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='TARGET_LANG'>

# %%
df['SOURCE_LANG'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='SOURCE_LANG'>

# %%
forecast_numbers = df['FORECAST'].value_counts()
plt.hist(forecast_numbers, bins=100)
plt.yscale('log')
plt.title('Histogram of FORECAST (log plot)')
plt.ylabel('Count')
plt.xlabel('Forecast')
plt.show()

# %%
df['QUALITY_EVALUATION'].value_counts().plot(kind='bar')
